# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 111.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 137.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 106.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 111.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 54.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 104.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]
# ...

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
print(df.duplicated().sum())
df[df.duplicated()].head()
# Out:
# 0
# Empty DataFrame
# ...

# %% [markdown]
# ### Task 2: Analysis of Duplicate Response Patterns
# 1. Identify duplicate response patterns based on selected columns such as MainBranch, Employment, and RemoteWork.
# 2. Clarify that these represent multiple respondents with identical answers rather than duplicate records. Analyse which other columns frequently share identical values within these response-pattern groups.

# %%
pattern_cols = ['MainBranch', 'Employment', 'RemoteWork']
duplicate_patterns = df[df.duplicated(subset=pattern_cols, keep=False)]
print("Number of records with duplicate response patterns:")
print(len(duplicate_patterns))
duplicate_patterns[pattern_cols].head()
df.groupby(pattern_cols).size().reset_index(name='Count').sort_values(by='Count', ascending=False).head()

pattern_groups = df.groupby(pattern_cols).size().reset_index(name='Count')
print(pattern_groups.sort_values('Count', ascending=False).head())

other_cols = [col for col in df.columns if col not in pattern_cols]
for col in other_cols:
    identical_groups = (df.groupby(pattern_cols)[col].nunique().eq(1).sum())
    print(f"{col}: {identical_groups}")
# Out:
# Number of records with duplicate response patterns:
# 65270
#                         MainBranch  \
# 0   I am a developer by profession
# 2   I am a developer by profession
# 1   I am a developer by profession
# 78  I am a developer by profession
# 8   I am a developer by profession
#
#                                            Employment  \
# 0                                 Employed, full-time
# 2                                 Employed, full-time
# 1                                 Employed, full-time
# 78  Independent contractor, freelancer, or self-em...
# 8   Employed, full-time;Independent contractor, fr...
#
#                               RemoteWork  Count
# 0   Hybrid (some remote, some in-person)  15286
# 2                                 Remote  12191
# 1                              In-person   7118
# 78                                Remote   2814
# 8                                 Remote   1754
# ResponseId: 130
# Age: 160
# Check: 449
# CodingActivities: 131
# ...

# %% [markdown]
# ### Task 3: Visualize Shared Response Patterns
# 1. Create visualizations to show the distribution of shared response patterns across different categories.
# 2. Use bar charts or pie charts to represent the distribution of respondents who share identical values for MainBranch, Employment, and RemoteWork, grouped by Country and Employment.

# %%
pattern_cols = ['MainBranch', 'Employment', 'RemoteWork']
pattern_counts = (df.groupby(pattern_cols).size().reset_index(name='Count').sort_values('Count', ascending=False))
print(pattern_counts.head())
top_patterns = pattern_counts.head(10)
plt.figure(figsize=(12,6))
labels = (top_patterns['MainBranch'] + ' | ' +top_patterns['Employment'] + ' | ' +top_patterns['RemoteWork'])
plt.bar(range(len(top_patterns)), top_patterns['Count'])
plt.xticks(range(len(top_patterns)), labels, rotation=90)
plt.xlabel('Response Pattern')
plt.ylabel('Number of Respondents')
plt.title('Top 10 Shared Response Patterns')
plt.tight_layout()
plt.show()

remote_counts = df['RemoteWork'].value_counts()
plt.figure(figsize=(8,5))
remote_counts.plot(kind='bar')
plt.title('Distribution of Respondents by Remote Work Preference')
plt.xlabel('Remote Work')
plt.ylabel('Count')
plt.show()

shared_patterns = df[df.duplicated(subset=pattern_cols, keep=False)]
country_employment_counts = (shared_patterns.groupby(['Country', 'Employment']).size().reset_index(name='Count').sort_values('Count', ascending=False))
top10 = country_employment_counts.head(10)
plt.figure(figsize=(12,6))
labels = top10['Country'] + ' - ' + top10['Employment']

plt.bar(labels, top10['Count'])
plt.xticks(rotation=90)
plt.xlabel('Country and Employment')
plt.ylabel('Number of Respondents')
plt.title('Top Shared Response Patterns by Country and Employment')
plt.tight_layout()
plt.show()

employment_counts = (shared_patterns.groupby('Employment').size().sort_values(ascending=False))
plt.figure(figsize=(8,8))
plt.pie(employment_counts,labels=employment_counts.index,autopct='%1.1f%%')
plt.title('Distribution of Shared Response Patterns by Employment')
plt.show()
# Out:
#                         MainBranch  \
# 0   I am a developer by profession
# 2   I am a developer by profession
# 1   I am a developer by profession
# 78  I am a developer by profession
# 8   I am a developer by profession
#
#                                            Employment  \
# 0                                 Employed, full-time
# 2                                 Employed, full-time
# 1                                 Employed, full-time
# 78  Independent contractor, freelancer, or self-em...
# 8   Employed, full-time;Independent contractor, fr...
#
#                               RemoteWork  Count
# 0   Hybrid (some remote, some in-person)  15286
# 2                                 Remote  12191
# 1                              In-person   7118
# 78                                Remote   2814
# 8                                 Remote   1754
# ...

# %% [markdown]
# ### Task 4: Evaluate Duplicate Handling Strategy
# 1. Analyse the dataset to determine which column(s) define record uniqueness.
# 2. Assess whether removing rows based on a subset of columns (rather than complete row duplication) is appropriate.
# Justify your decision with reference to the structure and purpose of the dataset.

# %% [raw]
# Analysis of the dataset indicates that ResponseId is the primary column that defines record uniqueness, as each response has a distinct identifier. Columns such as MainBranch, Employment, and RemoteWork contain many repeated values because multiple respondents can provide the same answers. Therefore, these survey-response columns should not be used to identify duplicate records. True duplicates should be detected using the unique respondent identifier (ResponseId) or by comparing all columns in a record.
# Removing rows based on a subset of columns is not appropriate for this survey dataset. The dataset is designed to collect responses from many individuals, and multiple respondents can legitimately share the same values for MainBranch, Employment, and RemoteWork. Removing such records would result in the loss of valid survey responses and could bias subsequent analysis. Duplicate handling should therefore focus on complete row duplication or unique identifiers such as ResponseId, rather than repeated answers to selected survey questions.

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# 1. Loading the survey dataset into a pandas DataFrame.
# 2. Detecting duplicate records using duplicated().
# 3. Reviewing duplicate rows to verify their presence.
# 4. Removing duplicates with drop_duplicates().
# 5. Confirming that no duplicate records remained.
# 6. Comparing row counts before and after cleaning to measure the number of duplicates removed.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# Specific columns should be selected for duplicate detection when those columns represent the true unique identifiers of a record. This approach prevents non-essential fields from affecting duplicate detection and helps identify repeated entities accurately.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
